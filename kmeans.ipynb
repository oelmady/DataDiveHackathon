# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('data/poverty_orrelations_by_country.csv')

df = df.drop('code', axis=1)
df = df.drop('Unnamed: 0', axis=1)

df = df.dropna()

# %%
df
# Out:
#      dep_infra_elec  dep_infra_imps  dep_infra_impw2  dep_educ_com  \
# 2         -0.008247       -0.039965        -0.007676     -0.046756
# 4          0.825961        0.608354         0.284614      0.644042
# 6          0.893473        0.281710         0.347174      0.724380
# 7          0.670889        0.396305         0.489295      0.602981
# 8          0.918493        0.621988         0.129122      0.871257
# ..              ...             ...              ...           ...
# 101        0.671258        0.355741         0.451220     -0.036136
# 102        0.322565        0.205984         0.056482      0.359435
# 103        0.110623        0.680578         0.832573      0.253168
# 104        0.780545        0.245345         0.694278      0.692604
# 105        0.887345        0.817203         0.814551      0.867732
#
#      dep_educ_enr  Deprivation rate in Electricity (%)  \
# 2       -0.322156                            -0.008247
# 4        0.407708                             0.825961
# 6        0.138331                             0.893473
# 7        0.645566                             0.670889
# 8        0.588603                             0.918493
# ..            ...                                  ...
# 101     -0.200042                             0.671258
# 102      0.269825                             0.322565
# 103      0.372243                             0.110623
# 104      0.736521                             0.780545
# 105      0.585776                             0.887345
#
#      Deprivation rate in Sanitation (%)  \
# 2                             -0.039965
# 4                              0.608354
# 6                              0.281710
# 7                              0.396305
# 8                              0.621988
# ..                                  ...
# 101                            0.355741
# 102                            0.205984
# 103                            0.680578
# 104                            0.245345
# 105                            0.817203
#
#      Deprivation rate in Drinking water (%)  \
# 2                                 -0.007676
# 4                                  0.284614
# 6                                  0.347174
# 7                                  0.489295
# 8                                  0.129122
# ..                                      ...
# 101                                0.451220
# 102                                0.056482
# 103                                0.832573
# 104                                0.694278
# 105                                0.814551
#
#      Deprivation rate in Educational attainment (%)  \
# 2                                         -0.046756
# 4                                          0.644042
# 6                                          0.724380
# 7                                          0.602981
# 8                                          0.871257
# ..                                              ...
# 101                                       -0.036136
# 102                                        0.359435
# 103                                        0.253168
# 104                                        0.692604
# 105                                        0.867732
#
#      Deprivation rate in Educational enrollment (%)
# 2                                         -0.322156
# 4                                          0.407708
# 6                                          0.138331
# 7                                          0.645566
# 8                                          0.588603
# ..                                              ...
# 101                                       -0.200042
# 102                                        0.269825
# 103                                        0.372243
# 104                                        0.736521
# 105                                        0.585776
#
# [76 rows x 10 columns]

# %%
kmeans = KMeans()

kmeans.fit(df)

clusters = pd.DataFrame(kmeans.cluster_centers_)

sns.heatmap(clusters)
# Out:
# <Axes: >
